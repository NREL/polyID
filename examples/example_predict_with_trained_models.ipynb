# %%
from polyid import MultiModel, SingleModel

from nfp.models import masked_mean_absolute_error
from nfp import GlobalUpdate, EdgeUpdate, NodeUpdate

from nfp.preprocessing.features import atom_features_v1, bond_features_v1

import pandas as pd

# %% [markdown]
# # Load in a prediction dataframe

# %%
dftest = pd.read_csv("../data/example_polymer_data_test.csv",index_col=0)
dftest.head()
# Out:
#                        hash-monomers-replicate_structure  \
# hash-monomers
# 4uXPpG64wgfkksqXD8DJpJ            JZYRZc8ofyyX6yAoXQ3CuU
# 4uXPpG64wgfkksqXD8DJpJ            4K4PkYwLKE446FFC9jndP2
# 6W6j2NAAV44kVGrQdVWw8V            f5SzKF3WSieMfutMEjNeH7
# 6W6j2NAAV44kVGrQdVWw8V            JxD9U5LiAcFQR8689KiPPj
# AthccWPLAQhXicTdNVLwr6            d2mRxaP8u3aTRGQdhBZHgD
#
#                                               smiles_monomer  \
# hash-monomers
# 4uXPpG64wgfkksqXD8DJpJ  O=C(O)CC/C=C/CCC(=O)O.OCCCCCCCCCCCCO
# 4uXPpG64wgfkksqXD8DJpJ  O=C(O)CC/C=C/CCC(=O)O.OCCCCCCCCCCCCO
# 6W6j2NAAV44kVGrQdVWw8V           O=C(O)c1ccc(C(=O)O)cc1.OCCO
# 6W6j2NAAV44kVGrQdVWw8V           O=C(O)c1ccc(C(=O)O)cc1.OCCO
# AthccWPLAQhXicTdNVLwr6                         NCCCCCCC(=O)O
#
#                                                            monomers  \
# hash-monomers
# 4uXPpG64wgfkksqXD8DJpJ  ('O=C(O)CC/C=C/CCC(=O)O', 'OCCCCCCCCCCCCO')
# 4uXPpG64wgfkksqXD8DJpJ  ('O=C(O)CC/C=C/CCC(=O)O', 'OCCCCCCCCCCCCO')
# 6W6j2NAAV44kVGrQdVWw8V           ('O=C(O)c1ccc(C(=O)O)cc1', 'OCCO')
# 6W6j2NAAV44kVGrQdVWw8V           ('O=C(O)c1ccc(C(=O)O)cc1', 'OCCO')
# AthccWPLAQhXicTdNVLwr6                           ('NCCCCCCC(=O)O',)
#
#                        distribution  replicate_structure  \
# hash-monomers
# 4uXPpG64wgfkksqXD8DJpJ           []                    0
# 4uXPpG64wgfkksqXD8DJpJ           []                    1
# 6W6j2NAAV44kVGrQdVWw8V           []                    0
# 6W6j2NAAV44kVGrQdVWw8V           []                    1
# AthccWPLAQhXicTdNVLwr6           []                    0
#
#                                                            smiles_polymer  \
# hash-monomers
# 4uXPpG64wgfkksqXD8DJpJ  O=C(O)CC/C=C/CCC(=O)OCCCCCCCCCCCCOC(=O)CC/C=C/...
# 4uXPpG64wgfkksqXD8DJpJ  O=C(O)CC/C=C/CCC(=O)OCCCCCCCCCCCCOC(=O)CC/C=C/...
# 6W6j2NAAV44kVGrQdVWw8V  O=C(O)c1ccc(C(=O)OCCOC(=O)c2ccc(C(=O)OCCOC(=O)...
# 6W6j2NAAV44kVGrQdVWw8V  O=C(O)c1ccc(C(=O)OCCOC(=O)c2ccc(C(=O)OCCOC(=O)...
# AthccWPLAQhXicTdNVLwr6  NCCCCCCC(=O)NCCCCCCC(=O)NCCCCCCC(=O)NCCCCCCC(=...
#
#                        mechanism     fake_Tg     fake_Tm
# hash-monomers
# 4uXPpG64wgfkksqXD8DJpJ     ester   58.488374  136.262792
# 4uXPpG64wgfkksqXD8DJpJ     ester  149.973928  192.983835
# 6W6j2NAAV44kVGrQdVWw8V     ester  222.833604  238.156834
# 6W6j2NAAV44kVGrQdVWw8V     ester   88.441712  154.833862
# AthccWPLAQhXicTdNVLwr6     amide   84.793010  152.571666

# %% [markdown]
# # Load Single Model

# %%
test_model = SingleModel.load_model("save_example/model_0/model_0.h5", "save_example/model_0/model_0_data.pk", custom_objects={   
        'GlobalUpdate': GlobalUpdate,
        'EdgeUpdate': EdgeUpdate,
        'NodeUpdate': NodeUpdate,
        'masked_mean_absolute_error': masked_mean_absolute_error
    })
# Out:
# 2022-08-24 09:10:53.372618: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
test_model.predict(test_model.df_train).head()
# Out:
# 306/306 [==============================] - 6s 17ms/step
#             hash-monomers hash-monomers-replicate_structure  \
# 0  KTMRo4rnwuxkaYBeBBwikU            8BeVeAaecM26mJCpTjTELx
# 1  KTMRo4rnwuxkaYBeBBwikU            ZHUvaQuU3tus4LvjQoXqDY
# 2  7eLJFKCkkELP6GUvN2o9HX            2QDcWhLHewjMGEZwQyfZXY
# 3  7eLJFKCkkELP6GUvN2o9HX            hcivJX2BDdsY4iTGhzWHE3
# 4  eg7sjgiCD3XRH8k6mJQQQv            Q65hS9Yjrto3Rtq9q9FWEt
#
#                                       smiles_monomer  \
# 0  CC1(C)CC(C)(c2ccc(Oc3ccc(-c4ccc(N)cc4)cc3C(F)(...
# 1  CC1(C)CC(C)(c2ccc(Oc3ccc(-c4ccc(N)cc4)cc3C(F)(...
# 2  C[Si](C)(c1ccc(C(=O)Nc2ccc(C(=O)O)cc2)cc1)c1cc...
# 3  C[Si](C)(c1ccc(C(=O)Nc2ccc(C(=O)O)cc2)cc1)c1cc...
# 4                    O=C(O)CCCCC(=O)O.OCCCCCCCCCCCCO
#
#                                             monomers distribution  \
# 0  ('CC1(C)CC(C)(c2ccc(Oc3ccc(-c4ccc(N)cc4)cc3C(F...           []
# 1  ('CC1(C)CC(C)(c2ccc(Oc3ccc(-c4ccc(N)cc4)cc3C(F...           []
# 2  ('C[Si](C)(c1ccc(C(=O)Nc2ccc(C(=O)O)cc2)cc1)c1...           []
# 3  ('C[Si](C)(c1ccc(C(=O)Nc2ccc(C(=O)O)cc2)cc1)c1...           []
# 4             ('O=C(O)CCCCC(=O)O', 'OCCCCCCCCCCCCO')           []
#
#    replicate_structure                                     smiles_polymer  \
# 0                    0  CC1(C)CC(C)(c2ccc(Oc3ccc(-c4ccc(NC(=O)c5cc(C(=...
# 1                    1  CC1(C)CC(C)(c2ccc(Oc3ccc(-c4ccc(NC(=O)c5cc(C(=...
# 2                    0  C[Si](C)(c1ccc(C(=O)Nc2ccc(C(=O)O)cc2)cc1)c1cc...
# 3                    1  C[Si](C)(c1ccc(C(=O)Nc2ccc(C(=O)O)cc2)cc1)c1cc...
# 4                    0  O=C(O)CCCCC(=O)OCCCCCCCCCCCCOC(=O)CCCCC(=O)OCC...
#
#   mechanism     fake_Tg     fake_Tm  data_id  fake_Tg_pred  fake_Tm_pred
# 0     amide  152.788535  194.728892        0     66.255676    188.442627
# 1     amide  -65.593807   59.331839        0     66.255676    188.442612
# 2     amide   89.063851  155.219588        1     56.494434    166.267593
# 3     amide  -18.280150   88.666307        1     56.494434    166.267593
# 4     ester  -88.285780   45.262816        2     48.376442    141.715637

# %%
test_model.predict(dftest).head()
# Out:
# 116/116 [==============================] - 2s 18ms/step
#                        hash-monomers-replicate_structure  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb            b8bdABaBWjX5o5E7ZTyiMQ
# 325Jvh8ND7qbmqeMPyYhKb            b8bdABaBWjX5o5E7ZTyiMQ
# 325Jvh8ND7qbmqeMPyYhKb            AB9huqKQpGn3y4usKmgCkT
# 325Jvh8ND7qbmqeMPyYhKb            AB9huqKQpGn3y4usKmgCkT
# 35KN4YENtyMVJHdf8AcomT            cGYPUzdYdmocXMYCgznWv9
#
#                                                            smiles_monomer  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb                  O=C(O)c1ccc2cc(C(=O)O)ccc2c1.OCCO
# 325Jvh8ND7qbmqeMPyYhKb                  O=C(O)c1ccc2cc(C(=O)O)ccc2c1.OCCO
# 325Jvh8ND7qbmqeMPyYhKb                  O=C(O)c1ccc2cc(C(=O)O)ccc2c1.OCCO
# 325Jvh8ND7qbmqeMPyYhKb                  O=C(O)c1ccc2cc(C(=O)O)ccc2c1.OCCO
# 35KN4YENtyMVJHdf8AcomT  O=C(O)CC(CC(=O)O)C(=O)O.OCCCCCCCCCCCOc1ccc(-c2...
#
#                                                                  monomers  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb           ('O=C(O)c1ccc2cc(C(=O)O)ccc2c1', 'OCCO')
# 325Jvh8ND7qbmqeMPyYhKb           ('O=C(O)c1ccc2cc(C(=O)O)ccc2c1', 'OCCO')
# 325Jvh8ND7qbmqeMPyYhKb           ('O=C(O)c1ccc2cc(C(=O)O)ccc2c1', 'OCCO')
# 325Jvh8ND7qbmqeMPyYhKb           ('O=C(O)c1ccc2cc(C(=O)O)ccc2c1', 'OCCO')
# 35KN4YENtyMVJHdf8AcomT  ('O=C(O)CC(CC(=O)O)C(=O)O', 'OCCCCCCCCCCCOc1cc...
#
#                        distribution  replicate_structure  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb           []                    0
# 325Jvh8ND7qbmqeMPyYhKb           []                    0
# 325Jvh8ND7qbmqeMPyYhKb           []                    1
# 325Jvh8ND7qbmqeMPyYhKb           []                    1
# 35KN4YENtyMVJHdf8AcomT           []                    0
#
#                                                            smiles_polymer  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb  O=C(O)c1ccc2cc(C(=O)OCCOC(=O)c3ccc4cc(C(=O)OCC...
# 325Jvh8ND7qbmqeMPyYhKb  O=C(O)c1ccc2cc(C(=O)OCCOC(=O)c3ccc4cc(C(=O)OCC...
# 325Jvh8ND7qbmqeMPyYhKb  O=C(O)c1ccc2cc(C(=O)OCCOC(=O)c3ccc4cc(C(=O)OCC...
# 325Jvh8ND7qbmqeMPyYhKb  O=C(O)c1ccc2cc(C(=O)OCCOC(=O)c3ccc4cc(C(=O)OCC...
# 35KN4YENtyMVJHdf8AcomT  O=C(O)CC(CC(=O)OCCCCCCCCCCCOc1ccc(-c2nnc(-c3cc...
#
#                        mechanism     fake_Tg     fake_Tm  fake_Tg_pred  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb     ester  215.870863  233.839935     55.101612
# 325Jvh8ND7qbmqeMPyYhKb     ester  215.870863  233.839935     55.101612
# 325Jvh8ND7qbmqeMPyYhKb     ester   38.291684  123.740844     55.101612
# 325Jvh8ND7qbmqeMPyYhKb     ester   38.291684  123.740844     55.101612
# 35KN4YENtyMVJHdf8AcomT     ester   70.565803  143.750798     50.106014
#
#                         fake_Tm_pred
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb    161.689865
# 325Jvh8ND7qbmqeMPyYhKb    161.689865
# 325Jvh8ND7qbmqeMPyYhKb    161.689865
# 325Jvh8ND7qbmqeMPyYhKb    161.689865
# 35KN4YENtyMVJHdf8AcomT    146.781708

# %% [markdown]
# # Load Multiple Models

# %%
mm = MultiModel.load_models("save_example")

# %% [markdown]
# ## Get predictions for every model

# %%
mm.make_predictions(dftest)
# Out:
# 116/116 [==============================] - 3s 21ms/step
# 116/116 [==============================] - 3s 18ms/step
# 116/116 [==============================] - 3s 17ms/step
#                        hash-monomers-replicate_structure  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb            b8bdABaBWjX5o5E7ZTyiMQ
# 325Jvh8ND7qbmqeMPyYhKb            b8bdABaBWjX5o5E7ZTyiMQ
# 325Jvh8ND7qbmqeMPyYhKb            AB9huqKQpGn3y4usKmgCkT
# 325Jvh8ND7qbmqeMPyYhKb            AB9huqKQpGn3y4usKmgCkT
# 35KN4YENtyMVJHdf8AcomT            cGYPUzdYdmocXMYCgznWv9
# ...                                                  ...
# oLNMgaS4JwmKLV9ZR6U4TC            YpUAwBDBvHXJmojfZzjs2J
# oW78BneYsXPoVUjxfW2DT5            AZMp23i74fNjEvtas6TCzD
# oW78BneYsXPoVUjxfW2DT5            AZMp23i74fNjEvtas6TCzD
# oW78BneYsXPoVUjxfW2DT5            2yNvYbmeCAwZKC8iLLrnM6
# oW78BneYsXPoVUjxfW2DT5            2yNvYbmeCAwZKC8iLLrnM6
#
#                                                            smiles_monomer  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb                  O=C(O)c1ccc2cc(C(=O)O)ccc2c1.OCCO
# 325Jvh8ND7qbmqeMPyYhKb                  O=C(O)c1ccc2cc(C(=O)O)ccc2c1.OCCO
# 325Jvh8ND7qbmqeMPyYhKb                  O=C(O)c1ccc2cc(C(=O)O)ccc2c1.OCCO
# 325Jvh8ND7qbmqeMPyYhKb                  O=C(O)c1ccc2cc(C(=O)O)ccc2c1.OCCO
# 35KN4YENtyMVJHdf8AcomT  O=C(O)CC(CC(=O)O)C(=O)O.OCCCCCCCCCCCOc1ccc(-c2...
# ...                                                                   ...
# oLNMgaS4JwmKLV9ZR6U4TC  Nc1ccc(Oc2ccc(N)cc2)cc1.O=C(CCl)Nc1cc(NC(=O)CC...
# oW78BneYsXPoVUjxfW2DT5  Nc1ccc(S2(c3ccc(N)cc3)C=C(c3ccccc3)C(c3ccccc3)...
# oW78BneYsXPoVUjxfW2DT5  Nc1ccc(S2(c3ccc(N)cc3)C=C(c3ccccc3)C(c3ccccc3)...
# oW78BneYsXPoVUjxfW2DT5  Nc1ccc(S2(c3ccc(N)cc3)C=C(c3ccccc3)C(c3ccccc3)...
# oW78BneYsXPoVUjxfW2DT5  Nc1ccc(S2(c3ccc(N)cc3)C=C(c3ccccc3)C(c3ccccc3)...
#
#                                                                  monomers  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb           ('O=C(O)c1ccc2cc(C(=O)O)ccc2c1', 'OCCO')
# 325Jvh8ND7qbmqeMPyYhKb           ('O=C(O)c1ccc2cc(C(=O)O)ccc2c1', 'OCCO')
# 325Jvh8ND7qbmqeMPyYhKb           ('O=C(O)c1ccc2cc(C(=O)O)ccc2c1', 'OCCO')
# 325Jvh8ND7qbmqeMPyYhKb           ('O=C(O)c1ccc2cc(C(=O)O)ccc2c1', 'OCCO')
# 35KN4YENtyMVJHdf8AcomT  ('O=C(O)CC(CC(=O)O)C(=O)O', 'OCCCCCCCCCCCOc1cc...
# ...                                                                   ...
# oLNMgaS4JwmKLV9ZR6U4TC  ('Nc1ccc(Oc2ccc(N)cc2)cc1', 'O=C(CCl)Nc1cc(NC(...
# oW78BneYsXPoVUjxfW2DT5  ('Nc1ccc(S2(c3ccc(N)cc3)C=C(c3ccccc3)C(c3ccccc...
# oW78BneYsXPoVUjxfW2DT5  ('Nc1ccc(S2(c3ccc(N)cc3)C=C(c3ccccc3)C(c3ccccc...
# oW78BneYsXPoVUjxfW2DT5  ('Nc1ccc(S2(c3ccc(N)cc3)C=C(c3ccccc3)C(c3ccccc...
# oW78BneYsXPoVUjxfW2DT5  ('Nc1ccc(S2(c3ccc(N)cc3)C=C(c3ccccc3)C(c3ccccc...
#
#                        distribution  replicate_structure  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb           []                    0
# 325Jvh8ND7qbmqeMPyYhKb           []                    0
# 325Jvh8ND7qbmqeMPyYhKb           []                    1
# 325Jvh8ND7qbmqeMPyYhKb           []                    1
# 35KN4YENtyMVJHdf8AcomT           []                    0
# ...                             ...                  ...
# oLNMgaS4JwmKLV9ZR6U4TC           []                    1
# oW78BneYsXPoVUjxfW2DT5           []                    0
# oW78BneYsXPoVUjxfW2DT5           []                    0
# oW78BneYsXPoVUjxfW2DT5           []                    1
# oW78BneYsXPoVUjxfW2DT5           []                    1
#
#                                                            smiles_polymer  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb  O=C(O)c1ccc2cc(C(=O)OCCOC(=O)c3ccc4cc(C(=O)OCC...
# 325Jvh8ND7qbmqeMPyYhKb  O=C(O)c1ccc2cc(C(=O)OCCOC(=O)c3ccc4cc(C(=O)OCC...
# 325Jvh8ND7qbmqeMPyYhKb  O=C(O)c1ccc2cc(C(=O)OCCOC(=O)c3ccc4cc(C(=O)OCC...
# 325Jvh8ND7qbmqeMPyYhKb  O=C(O)c1ccc2cc(C(=O)OCCOC(=O)c3ccc4cc(C(=O)OCC...
# 35KN4YENtyMVJHdf8AcomT  O=C(O)CC(CC(=O)OCCCCCCCCCCCOc1ccc(-c2nnc(-c3cc...
# ...                                                                   ...
# oLNMgaS4JwmKLV9ZR6U4TC  Nc1ccc(Oc2ccc(NC(=O)c3cc(NC(=O)c4cc(NC(=O)CCl)...
# oW78BneYsXPoVUjxfW2DT5  Nc1ccc(S2(c3ccc(NC(=O)Cc4ccc(-c5sc(-c6ccc(CC(=...
# oW78BneYsXPoVUjxfW2DT5  Nc1ccc(S2(c3ccc(NC(=O)Cc4ccc(-c5sc(-c6ccc(CC(=...
# oW78BneYsXPoVUjxfW2DT5  Nc1ccc(S2(c3ccc(NC(=O)Cc4ccc(-c5sc(-c6ccc(CC(=...
# oW78BneYsXPoVUjxfW2DT5  Nc1ccc(S2(c3ccc(NC(=O)Cc4ccc(-c5sc(-c6ccc(CC(=...
#
#                        mechanism     fake_Tg     fake_Tm  fake_Tg_pred  \
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb     ester  215.870863  233.839935     81.854759
# 325Jvh8ND7qbmqeMPyYhKb     ester  215.870863  233.839935     81.854759
# 325Jvh8ND7qbmqeMPyYhKb     ester   38.291684  123.740844     81.854759
# 325Jvh8ND7qbmqeMPyYhKb     ester   38.291684  123.740844     81.854759
# 35KN4YENtyMVJHdf8AcomT     ester   70.565803  143.750798     80.969093
# ...                          ...         ...         ...           ...
# oLNMgaS4JwmKLV9ZR6U4TC     amide   50.301855  131.187150     64.332329
# oW78BneYsXPoVUjxfW2DT5     amide   49.412002  130.635441     65.197784
# oW78BneYsXPoVUjxfW2DT5     amide   49.412002  130.635441     65.197784
# oW78BneYsXPoVUjxfW2DT5     amide  166.583024  203.281475     65.197784
# oW78BneYsXPoVUjxfW2DT5     amide  166.583024  203.281475     65.197784
#
#                         fake_Tm_pred model_id
# hash-monomers
# 325Jvh8ND7qbmqeMPyYhKb    140.118881        2
# 325Jvh8ND7qbmqeMPyYhKb    140.118881        2
# 325Jvh8ND7qbmqeMPyYhKb    140.118881        2
# 325Jvh8ND7qbmqeMPyYhKb    140.118881        2
# 35KN4YENtyMVJHdf8AcomT    138.553635        2
# ...                              ...      ...
# oLNMgaS4JwmKLV9ZR6U4TC    126.490631        1
# oW78BneYsXPoVUjxfW2DT5    128.158951        1
# oW78BneYsXPoVUjxfW2DT5    128.158951        1
# oW78BneYsXPoVUjxfW2DT5    128.158951        1
# oW78BneYsXPoVUjxfW2DT5    128.158951        1
#
# [696 rows x 12 columns]

# %% [markdown]
# ## Aggregate results together

# %%
mm.make_aggregate_predictions(dftest).head()
# Out:
# 116/116 [==============================] - 2s 20ms/step
# 116/116 [==============================] - 2s 17ms/step
# 116/116 [==============================] - 2s 19ms/step
#   distribution_                                    smiles_monomer_  \
# 0            []  CC(C)(C)c1cc(C(=O)O)cc(C(=O)O)c1.Nc1ccc(-c2ccc...
# 1            []                          CC(C)(CO)CO.O=C(O)CC(=O)O
# 2            []  CC(C)(c1ccc(Oc2ccc(C(=O)O)c(C(=O)O)c2)cc1)c1cc...
# 3            []  CC(C)(c1ccc(Oc2ccc(N)cc2)cc1)c1ccc(Oc2ccc(N)cc...
# 4            []                         CC(CCC(=O)O)CC(=O)O.OCCCCO
#
#    fake_Tg_mean  fake_Tm_mean  fake_Tg_pred_mean  fake_Tm_pred_mean
# 0     36.555413    122.664356          71.319382         152.994476
# 1    123.012814    176.267945          59.351757         125.104080
# 2     41.897381    125.976376          66.527573         141.876556
# 3     53.047122    132.889216          68.453239         145.458954
# 4    -66.870841     58.540079          60.429699         127.286690

# %% [markdown]
# ## Specify Aggregate Function

# %%
mm.make_aggregate_predictions(dftest, funcs=["mean"]).head()
# Out:
# 116/116 [==============================] - 3s 21ms/step
# 116/116 [==============================] - 2s 21ms/step
# 116/116 [==============================] - 2s 18ms/step
#   distribution_                                    smiles_monomer_  \
# 0            []  CC(C)(C)c1cc(C(=O)O)cc(C(=O)O)c1.Nc1ccc(-c2ccc...
# 1            []                          CC(C)(CO)CO.O=C(O)CC(=O)O
# 2            []  CC(C)(c1ccc(Oc2ccc(C(=O)O)c(C(=O)O)c2)cc1)c1cc...
# 3            []  CC(C)(c1ccc(Oc2ccc(N)cc2)cc1)c1ccc(Oc2ccc(N)cc...
# 4            []                         CC(CCC(=O)O)CC(=O)O.OCCCCO
#
#    fake_Tg_mean  fake_Tm_mean  fake_Tg_pred_mean  fake_Tm_pred_mean
# 0     36.555413    122.664356          71.319382         152.994476
# 1    123.012814    176.267945          59.351757         125.104080
# 2     41.897381    125.976376          66.527573         141.876556
# 3     53.047122    132.889216          68.453239         145.458954
# 4    -66.870841     58.540079          60.429699         127.286690
