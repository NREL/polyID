# %%
from polyid import DoV
import pandas as pd

dov = DoV()
# Out:
# 2023-08-10 19:41:10.700786: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Get the fingerprints for a single molecule

# %%
smiles = "C=CCC(O)CCC(O)CC"
pd.DataFrame(dov.get_fp(smiles)).T
# Out:
#                   535847852   864662311   1506563592  1506997381  1542633699  \
# C=CCC(O)CCC(O)CC           1           2           1           1           2
#
#                   1583799011  1674219510  2245273601  2245384272  2246703798  \
# C=CCC(O)CCC(O)CC           2           2           2           4           1
#
#                   2246728737  2246997334  2380228464  2690477299  2879529074  \
# C=CCC(O)CCC(O)CC           1           1           1           1           2
#
#                   2928069067  3321103681  3337365384  3542456614  3696402029
# C=CCC(O)CCC(O)CC           1           1           1           1           1

# %% [markdown]
# # Get the Fingerprints for a Dataframes and Find Overlaping Fingerprints

# %%
# import data
dftrain = pd.read_csv('../data/dftrain.csv',index_col=0)
dftest = pd.read_csv('../data/dftest.csv',index_col=0)

# # split training and prediction dataframes for only one example replicate strucuture into example train and prediction dataframes
# data = data[data.replicate_structure==0]
# dftrain = data.iloc[0:231]
# dfpredict = data.iloc[231:289]

# generate fingerprint dataframe for training set
dftrain_fps = dov.get_fps(dftrain)
dftrain_fps.head()
# Out:
# 100%|██████████| 765/765 [00:07<00:00, 103.15it/s]
#                         150310      953614      1789498     3624155     \
# hash-monomers
# 97HajcX4DAqPdgC7WQPRWE         0.0         0.0         0.0         0.0
# RTGnTgkoahG8XtT2v6rL65         0.0         2.0         0.0         0.0
# XSug3HHV8utUy5mY9rSA2s         0.0         0.0         0.0         0.0
# UwUnxrPBAjA9dQhSBQ7Svc         0.0         0.0         0.0         0.0
# FQCWapvWuN8Wre4WFw85Qp         0.0         0.0         0.0         0.0
#
#                         8122915     10565946    12149854    13011249    \
# hash-monomers
# 97HajcX4DAqPdgC7WQPRWE         0.0         0.0         0.0         0.0
# RTGnTgkoahG8XtT2v6rL65         0.0         0.0         0.0         0.0
# XSug3HHV8utUy5mY9rSA2s         0.0        16.0         0.0         0.0
# UwUnxrPBAjA9dQhSBQ7Svc         0.0        16.0         0.0         0.0
# FQCWapvWuN8Wre4WFw85Qp         0.0        16.0         0.0         0.0
#
#                         13251412    14329011    ...  4266420978  4272365792  \
# hash-monomers                                   ...
# 97HajcX4DAqPdgC7WQPRWE         0.0         0.0  ...         0.0         0.0
# RTGnTgkoahG8XtT2v6rL65         0.0         0.0  ...         0.0         0.0
# XSug3HHV8utUy5mY9rSA2s         0.0         0.0  ...         0.0         0.0
# UwUnxrPBAjA9dQhSBQ7Svc         0.0         0.0  ...         0.0         0.0
# FQCWapvWuN8Wre4WFw85Qp         0.0         0.0  ...         0.0         0.0
#
#                         4274868290  4276070277  4277401654  4277669517  \
# hash-monomers
# 97HajcX4DAqPdgC7WQPRWE         0.0         0.0         0.0         0.0
# RTGnTgkoahG8XtT2v6rL65         0.0         0.0         0.0         0.0
# XSug3HHV8utUy5mY9rSA2s         0.0         0.0         0.0         0.0
# UwUnxrPBAjA9dQhSBQ7Svc         0.0         0.0         0.0         0.0
# FQCWapvWuN8Wre4WFw85Qp         0.0         0.0         0.0         0.0
#
#                         4278542436  4278941385  4279130151  4283358858
# hash-monomers
# 97HajcX4DAqPdgC7WQPRWE         0.0         0.0         0.0         0.0
# RTGnTgkoahG8XtT2v6rL65         0.0         0.0         0.0         0.0
# XSug3HHV8utUy5mY9rSA2s         0.0         1.0         0.0         0.0
# UwUnxrPBAjA9dQhSBQ7Svc         0.0         0.0         0.0         0.0
# FQCWapvWuN8Wre4WFw85Qp         0.0         0.0         0.0         0.0
#
# [5 rows x 2322 columns]

# %%
# calculate the number of fingerprints found in the prediction polymers that are not in the training set polymers (fps_notin_train)
dftest_dov = dov.get_fps_overlap(dftest,dftrain_fps)
dftest_dov.head()
# Out:
# 100%|██████████| 192/192 [00:01<00:00, 112.18it/s]
#                        hash-monomers-replicate_structure  \
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc            nSq4qApjYYfQotWy6eUcb5
# DnzPnw24EM67jatixUH2MB            8AZMDgoTjAid4jUHVHgqUm
# Lw7FPQkTo7Lc6nZSd2enr6            6PAbuiGtt6XHFyzoYCuD6L
# iQWXgGECwJEWrYDQJUnnTJ            GoLZDp4A8qf8YfPqjLxdmS
# 2ncbwz6Qphb5SEQ7japXS4            ed5U2tPP7wLuLLhEiFguHa
#
#                                                            smiles_monomer  \
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc  Nc1c(F)cc(Cc2cc(F)c(N)c(F)c2)cc1F.O=C1OC(=O)c2...
# DnzPnw24EM67jatixUH2MB  O=C(O)c1ccc(C(=O)O)cc1.Nc1ccc(-c2ccc(Oc3ccc4c(...
# Lw7FPQkTo7Lc6nZSd2enr6  Nc1ccc(Oc2ccc(N)cc2)cc1.O=C(c1cccc(C(=O)c2ccc3...
# iQWXgGECwJEWrYDQJUnnTJ  O=C(O)c1ccc(Oc2ccc(-c3cccc(-c4ccc(Oc5ccc(C(=O)...
# 2ncbwz6Qphb5SEQ7japXS4                                    C=C(C)CC(=O)OCC
#
#                                                                  monomers  \
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc  ('Nc1c(F)cc(Cc2cc(F)c(N)c(F)c2)cc1F', 'O=C1OC(...
# DnzPnw24EM67jatixUH2MB  ('O=C(O)c1ccc(C(=O)O)cc1', 'Nc1ccc(-c2ccc(Oc3c...
# Lw7FPQkTo7Lc6nZSd2enr6  ('Nc1ccc(Oc2ccc(N)cc2)cc1', 'O=C(c1cccc(C(=O)c...
# iQWXgGECwJEWrYDQJUnnTJ  ('O=C(O)c1ccc(Oc2ccc(-c3cccc(-c4ccc(Oc5ccc(C(=...
# 2ncbwz6Qphb5SEQ7japXS4                               ('C=C(C)CC(=O)OCC',)
#
#                        mechanism  Density  Glass_Transition  Melt_Temp  \
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc     imide      NaN             300.3        NaN
# DnzPnw24EM67jatixUH2MB     amide     1.31             278.0        NaN
# Lw7FPQkTo7Lc6nZSd2enr6     imide      NaN             266.0        NaN
# iQWXgGECwJEWrYDQJUnnTJ     amide     1.58             248.0        NaN
# 2ncbwz6Qphb5SEQ7japXS4     vinyl      NaN             106.0        NaN
#
#                         log10_Permeability_CO2  log10_Permeability_N2  \
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc                     NaN                    NaN
# DnzPnw24EM67jatixUH2MB                1.278754              -0.060481
# Lw7FPQkTo7Lc6nZSd2enr6                     NaN                    NaN
# iQWXgGECwJEWrYDQJUnnTJ                1.602060               0.204120
# 2ncbwz6Qphb5SEQ7japXS4                     NaN                    NaN
#
#                         log10_Permeability_O2  YoungMod distribution  \
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc                    NaN    2600.0           []
# DnzPnw24EM67jatixUH2MB               0.886491   44100.0           []
# Lw7FPQkTo7Lc6nZSd2enr6                    NaN    1309.0           []
# iQWXgGECwJEWrYDQJUnnTJ                    NaN    1040.5           []
# 2ncbwz6Qphb5SEQ7japXS4                    NaN       NaN           []
#
#                         replicate_structure  \
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc                    0
# DnzPnw24EM67jatixUH2MB                    0
# Lw7FPQkTo7Lc6nZSd2enr6                    0
# iQWXgGECwJEWrYDQJUnnTJ                    0
# 2ncbwz6Qphb5SEQ7japXS4                    0
#
#                                                            smiles_polymer  \
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc  Nc1c(F)cc(Cc2cc(F)c(N3C(=O)c4ccc(C(c5ccc6c(c5)...
# DnzPnw24EM67jatixUH2MB  Nc1ccc(-c2ccc(Oc3ccc4c(c3)Oc3cc(Oc5ccc(-c6ccc(...
# Lw7FPQkTo7Lc6nZSd2enr6  Nc1ccc(Oc2ccc(N3C(=O)c4ccc(C(=O)c5cccc(C(=O)c6...
# iQWXgGECwJEWrYDQJUnnTJ  Nc1ccc(-c2ccc(Oc3ccc(C4(c5ccc(Oc6ccc(-c7ccc(NC...
# 2ncbwz6Qphb5SEQ7japXS4  CCOC(=O)CC(C)CCC(C)(CC(=O)OCC)C(C)(CCC(C)(CC(=...
#
#                         fps_notin_train
# hash-monomers
# PZgAzjfcwxsq8aRknneVHc                0
# DnzPnw24EM67jatixUH2MB                0
# Lw7FPQkTo7Lc6nZSd2enr6                0
# iQWXgGECwJEWrYDQJUnnTJ                1
# 2ncbwz6Qphb5SEQ7japXS4               20
